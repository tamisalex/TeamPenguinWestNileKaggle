# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
from IPython.display import HTML 
HTML('<iframe width="1200" height="800" src=https://public.tableau.com/views/tabMap/Dashboard1?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1200" height="800" src=https://public.tableau.com/views/tabMap/Dashboard1?:showVizHome=no&:embed=true frameborder="0" allowfullscreen></iframe>

# %%
df = pd.read_csv('../assets/train.csv')

# %%
df.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
sns.distplot(df.NumMosquitos)

# %%
# plt.RcParams(figsize=(20,10))
a = sns.factorplot(
    x='Species',
    y='NumMosquitos',
    data=df, 
    kind='box',
    size=10
)
a.set_xticklabels(rotation=30)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.head(1)
# Out:
#                                                       Address  \
# Date
# 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                            Species  Block           Street  Trap  \
# Date
# 2007-05-29  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#                        AddressNumberAndStreet  Latitude  Longitude  \
# Date
# 2007-05-29  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991
#
#             AddressAccuracy  NumMosquitos  WnvPresent
# Date
# 2007-05-29                9             1           0

# %%
df[['NumMosquitos']].plot()

# %%
#Well that's not very helpful with the missing years
a = df['WnvPresent'].resample('W', how='count')
# Out:
# /Users/michaelmainzer/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   from ipykernel import kernelapp as app

# %%
a.plot()

# %%
ax = sns.tsplot(data=a, ci=[68, 95], color="m")
