# %%
import pandas as pd

# %%
test = pd.read_csv("../assets/test.csv")
train = pd.read_csv("../assets/train.csv")
spray = pd.read_csv("../assets/spray.csv")
weather = pd.read_csv("../assets/weather.csv")

# %%
train["spray"] = 0
spray["spray"] = 1

# %%
trainAndSpray = pd.DataFrame()
trainAndSpray = trainAndSpray.append(train)
trainAndSpray = trainAndSpray.append(spray)

trainAndSpray
# Out:
#                                                  Address  AddressAccuracy  \
# 0      4100 North Oak Park Avenue, Chicago, IL 60634,...              9.0
# 1      4100 North Oak Park Avenue, Chicago, IL 60634,...              9.0
# 2      6200 North Mandell Avenue, Chicago, IL 60646, USA              9.0
# 3        7900 West Foster Avenue, Chicago, IL 60656, USA              8.0
# 4        7900 West Foster Avenue, Chicago, IL 60656, USA              8.0
# 5       1500 West Webster Avenue, Chicago, IL 60614, USA              8.0
# 6         2500 West Grand Avenue, Chicago, IL 60654, USA              8.0
# 7            1100 Roosevelt Road, Chicago, IL 60608, USA              8.0
# 8            1100 Roosevelt Road, Chicago, IL 60608, USA              8.0
# 9       1100 West Chicago Avenue, Chicago, IL 60642, USA              8.0
# 10       2100 North Stave Street, Chicago, IL 60647, USA              8.0
# 11       2200 North Cannon Drive, Chicago, IL 60614, USA              8.0
# ...

# %%
trainAndSpray.to_csv("../assets/trainAndSpray.csv")
